# %% [markdown]
# # Importing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("bengaluru_house_prices.csv")

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.head(1)
# Out:
#               area_type availability                  location   size  \
# 0  Super built-up  Area       19-Dec  Electronic City Phase II  2 BHK
#
#    society total_sqft  bath  balcony  price
# 0  Coomee        1056   2.0      1.0  39.07

# %%
df.tail(1)
# Out:
#                   area_type   availability      location   size society  \
# 13319  Super built-up  Area  Ready To Move  Doddathoguru  1 BHK     NaN
#
#       total_sqft  bath  balcony  price
# 13319        550   1.0      1.0   17.0

# %%
df.sample(5)
# Out:
#                   area_type   availability               location   size  \
# 9238         Built-up  Area  Ready To Move   Lakshminarayana Pura  2 BHK
# 1293   Super built-up  Area         18-Jul              Hosa Road  3 BHK
# 11877  Super built-up  Area  Ready To Move         Sarjapur  Road  4 BHK
# 13214          Carpet  Area  Ready To Move      Bannerghatta Road  3 BHK
# 12911  Super built-up  Area  Ready To Move  Kanakapura main  Road  3 BHK
#
#        society total_sqft  bath  balcony   price
# 9238   RothaVa       1169   2.0      2.0   75.00
# 1293   Mahesr        1726   3.0      2.0   81.99
# 11877  Adeatlm       3335   4.0      3.0  300.00
# 13214  Vemit S       1470   2.0      1.0   85.00
# 12911      NaN       1495   2.0      2.0   52.33

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
L=[]
for i in df['total_sqft']:
    s=i.split(" - ")
    if s[0].isdigit() :
        L.append(int(s[0]))
    else:
        L.append(np.nan)

# %%
df['total_sqft1']=L

# %%
df[['total_sqft','total_sqft1']]
# Out:
#       total_sqft  total_sqft1
# 0           1056       1056.0
# 1           2600       2600.0
# 2           1440       1440.0
# 3           1521       1521.0
# 4           1200       1200.0
# ...          ...          ...
# 13315       3453       3453.0
# 13316       3600       3600.0
# 13317       1141       1141.0
# 13318       4689       4689.0
# 13319        550        550.0
#
# [13320 rows x 2 columns]

# %%
df[['total_sqft','total_sqft1']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   total_sqft   13320 non-null  object
#  1   total_sqft1  13182 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 208.3+ KB

# %%
df.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# total_sqft1      138
# dtype: int64

# %%
df.isna().mean()*100
# Out:
# area_type        0.000000
# availability     0.000000
# location         0.007508
# size             0.120120
# society         41.306306
# total_sqft       0.000000
# bath             0.548048
# balcony          4.572072
# price            0.000000
# total_sqft1      1.036036
# dtype: float64

# %%
df.drop(columns="society",inplace=True)
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12579 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12579 non-null  object
#  1   availability  12579 non-null  object
#  2   location      12579 non-null  object
#  3   size          12579 non-null  object
#  4   total_sqft    12579 non-null  object
#  5   bath          12579 non-null  float64
#  6   balcony       12579 non-null  float64
#  7   price         12579 non-null  float64
#  8   total_sqft1   12579 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 982.7+ KB

# %%
#L=[]
#for i in df['total_sqft']:
#    L.append(i.split())
#print(L)

# %%
#for i in L:
#    if  i[0].isalnum() and not i[0].isdigit():
#        i[0]=np.nan

# %%
#for i in L:
#    if not i[0].isalnum():
#        print(i[0], L.index(i),sep=" : ")

# %%
#L[410][0]=np.nan

# %%
#for i in L:
#    if not str(i[0]).isdigit():
#        print(i[0])

# %%
df.isna().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# total_sqft1     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 563

# %%
df.describe()
# Out:
#                bath       balcony         price   total_sqft1
# count  12579.000000  12579.000000  12579.000000  12579.000000
# mean       2.613880      1.586295    105.709331   1509.243104
# std        1.225025      0.817165    131.873587   1164.083210
# min        1.000000      0.000000      8.000000      5.000000
# 25%        2.000000      1.000000     49.000000   1100.000000
# 50%        2.000000      2.000000     70.000000   1258.000000
# 75%        3.000000      2.000000    114.500000   1636.000000
# max       40.000000      3.000000   2912.000000  52272.000000

# %%
df.describe(include="O")
# Out:
#                    area_type   availability    location   size total_sqft
# count                  12579          12579       12579  12579      12579
# unique                     4             77        1257     27       1860
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK       1200
# freq                    8405           9989         513   5124        788

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price  total_sqft1
# 0          2 BHK       1056   2.0      1.0   39.07       1056.0
# 1      4 Bedroom       2600   5.0      3.0  120.00       2600.0
# 2          3 BHK       1440   2.0      3.0   62.00       1440.0
# 3          3 BHK       1521   3.0      1.0   95.00       1521.0
# 4          2 BHK       1200   2.0      1.0   51.00       1200.0
# ...          ...        ...   ...      ...     ...          ...
# 13314      3 BHK       1715   3.0      3.0  112.00       1715.0
# 13315  5 Bedroom       3453   4.0      0.0  231.00       3453.0
# 13317      2 BHK       1141   2.0      1.0   60.00       1141.0
# 13318      4 BHK       4689   4.0      1.0  488.00       4689.0
# 13319      1 BHK        550   1.0      1.0   17.00        550.0
#
# [12579 rows x 9 columns]

# %%
plt.figure(figsize=(15,8))
c=1
for i in df.describe().columns:
    plt.subplot(3,3,c)
    sns.boxplot(x=df[i])
    plt.tight_layout()
    c+=1

# %%
df['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-Feb', '18-Nov', '18-May', '20-Dec',
#        '17-Oct', '21-Dec', '20-Sep', '18-Mar', '18-Apr', '20-Aug',
#        '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr', '18-Jun',
#        '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul', '18-Jul',
#        '21-Jun', '20-May', '19-Aug', '18-Sep', '17-May', '17-Jun',
#        '18-Oct', '21-May', '18-Jan', '20-Mar', '17-Dec', '16-Mar',
#        '19-Jun', '22-Jun', '19-Jul', '21-Feb', '19-May', '17-Nov',
#        '20-Oct', '20-Jun', '19-Feb', '21-Oct', '21-Jan', '17-Mar',
#        '19-Sep', '17-Apr', '19-Oct', '21-Jul', '21-Nov', '21-Mar',
#        '16-Dec', '22-Mar', '20-Jan', '21-Sep', '21-Aug', '14-Nov',
#        '19-Nov', '16-Jul', '15-Jun', '20-Nov', '20-Jul', '16-Sep',
#        '20-Feb', '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan',
#        '16-Nov', '20-Apr', '16-Jan', '17-Feb', '14-Jul'], dtype=object)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size total_sqft  bath  balcony   price  total_sqft1
# 0          2 BHK       1056   2.0      1.0   39.07       1056.0
# 1      4 Bedroom       2600   5.0      3.0  120.00       2600.0
# 2          3 BHK       1440   2.0      3.0   62.00       1440.0
# 3          3 BHK       1521   3.0      1.0   95.00       1521.0
# 4          2 BHK       1200   2.0      1.0   51.00       1200.0
# ...          ...        ...   ...      ...     ...          ...
# 13314      3 BHK       1715   3.0      3.0  112.00       1715.0
# 13315  5 Bedroom       3453   4.0      0.0  231.00       3453.0
# 13317      2 BHK       1141   2.0      1.0   60.00       1141.0
# 13318      4 BHK       4689   4.0      1.0  488.00       4689.0
# 13319      1 BHK        550   1.0      1.0   17.00        550.0
#
# [12579 rows x 9 columns]

# %%
df.drop(columns=["availability","total_sqft"],inplace=True)

# %%
df
# Out:
#                   area_type                  location       size  bath  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK   2.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom   5.0
# 2            Built-up  Area               Uttarahalli      3 BHK   2.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK   3.0
# 4      Super built-up  Area                  Kothanur      2 BHK   2.0
# ...                     ...                       ...        ...   ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK   3.0
# 13315        Built-up  Area                Whitefield  5 Bedroom   4.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK   2.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK   4.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK   1.0
#
#        balcony   price  total_sqft1
# 0          1.0   39.07       1056.0
# 1          3.0  120.00       2600.0
# 2          3.0   62.00       1440.0
# 3          1.0   95.00       1521.0
# 4          1.0   51.00       1200.0
# ...        ...     ...          ...
# 13314      3.0  112.00       1715.0
# 13315      0.0  231.00       3453.0
# 13317      1.0   60.00       1141.0
# 13318      1.0  488.00       4689.0
# 13319      1.0   17.00        550.0
#
# [12579 rows x 7 columns]

# %%
df.rename(columns={'total_sqft1': 'total_sqft'}, inplace=True)

# %%
df
# Out:
#                   area_type                  location       size  bath  \
# 0      Super built-up  Area  Electronic City Phase II      2 BHK   2.0
# 1                Plot  Area          Chikka Tirupathi  4 Bedroom   5.0
# 2            Built-up  Area               Uttarahalli      3 BHK   2.0
# 3      Super built-up  Area        Lingadheeranahalli      3 BHK   3.0
# 4      Super built-up  Area                  Kothanur      2 BHK   2.0
# ...                     ...                       ...        ...   ...
# 13314  Super built-up  Area         Green Glen Layout      3 BHK   3.0
# 13315        Built-up  Area                Whitefield  5 Bedroom   4.0
# 13317        Built-up  Area     Raja Rajeshwari Nagar      2 BHK   2.0
# 13318  Super built-up  Area           Padmanabhanagar      4 BHK   4.0
# 13319  Super built-up  Area              Doddathoguru      1 BHK   1.0
#
#        balcony   price  total_sqft
# 0          1.0   39.07      1056.0
# 1          3.0  120.00      2600.0
# 2          3.0   62.00      1440.0
# 3          1.0   95.00      1521.0
# 4          1.0   51.00      1200.0
# ...        ...     ...         ...
# 13314      3.0  112.00      1715.0
# 13315      0.0  231.00      3453.0
# 13317      1.0   60.00      1141.0
# 13318      1.0  488.00      4689.0
# 13319      1.0   17.00       550.0
#
# [12579 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# 684

# %%
df.isna().sum()
# Out:
# area_type     0
# location      0
# size          0
# bath          0
# balcony       0
# price         0
# total_sqft    0
# dtype: int64
